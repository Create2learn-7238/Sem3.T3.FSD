# %% [markdown]
# ## custom Exception

# %%
class dixit(Exception):
    def __init__(self,arg):
        self.msg=arg

# %%
def add(a,b):
    if type(a)==str:
        raise dixit("My msg")
    if type(b)==str:
        raise TypeError("B should not be String")
add("ABC","pqr")
# Out:
# ---------------------------------------------------------------------------
# dixit                                     Traceback (most recent call last)
# <ipython-input-2-e1b73997dfee> in <module>
#       4     if type(b)==str:
#       5         raise TypeError("B should not be String")
# ----> 6 add("ABC","pqr")
#
# <ipython-input-2-e1b73997dfee> in add(a, b)
#       1 def add(a,b):
#       2     if type(a)==str:
# ----> 3         raise dixit("My msg")
#       4     if type(b)==str:
#       5         raise TypeError("B should not be String")
#
# dixit: My msg

# %%
def check():
    money=10000
    withdraw=int(input("Enter widhraw amt : "))
    try:
        if withdraw>money:
            raise TypeError("You cant Withdraw more then balance")
        elif balance<=2000:
            balance=money-withdraw
            print(balance)
            raise dixit("Error 2000: Low balance")
        else :
            balance=money-withdraw
            print("Withdraw :",withdraw)
            print("Remaining :",balance)
    except (dixit,TypeError) as d:
        print(d)
        
check()
# Out:
# Enter widhraw amt : 200000
# You cant Withdraw more then balance
